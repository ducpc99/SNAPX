# %%
import pandas as pd

# Đọc dữ liệu từ cả hai file
snap_df = pd.read_csv('datasets/S-NAP.csv')
snap_instructions_df = pd.read_csv('datasets/S-NAP_instructions.csv')

# Hiển thị các cột trong cả hai file
print("Cột trong S-NAP.csv:", snap_df.columns)
print("Cột trong S-NAP_instructions.csv:", snap_instructions_df.columns)

# Kiểm tra số dòng trong mỗi file
print("Số dòng trong S-NAP.csv:", snap_df.shape[0])
print("Số dòng trong S-NAP_instructions.csv:", snap_instructions_df.shape[0])

# Kiểm tra một số dòng đầu tiên để so sánh cấu trúc dữ liệu
print("Dữ liệu đầu tiên trong S-NAP.csv:")
print(snap_df.head())

print("Dữ liệu đầu tiên trong S-NAP_instructions.csv:")
print(snap_instructions_df.head())
# Out:
# Cột trong S-NAP.csv: Index(['model_id', 'revision_id', 'trace', 'prefix', 'next',
#        'unique_activities', 'id'],
#       dtype='object')
# Cột trong S-NAP_instructions.csv: Index(['id', 'unique_activities', 'instruction', 'output', 'instruction_type',
#        'variant', 'prefix', 'trace', 'next'],
#       dtype='object')
# Số dòng trong S-NAP.csv: 1289081
# Số dòng trong S-NAP_instructions.csv: 575339
# Dữ liệu đầu tiên trong S-NAP.csv:
#                            model_id                       revision_id  \
# 0  e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 1  e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 2  e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 3  e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
# 4  e8990a10f516495e89a1eabf9627b9e9  295ab34872b6424aad0b4633abb621a9
#
#                                                trace  \
# 0  ['Add personal data', 'Select necessary work e...
# ...
